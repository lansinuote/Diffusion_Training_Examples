# %%
from diffusers import DiffusionPipeline
from matplotlib import pyplot as plt
# %matplotlib inline
import torch


def test(pipeline):
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    pipeline = pipeline.to(device)

    images = pipeline('A photo of sks dog in a bucket',
                      num_images_per_prompt=4).images

    plt.figure(figsize=(10, 5))
    for i in range(4):
        plt.subplot(1, 4, i + 1)
        plt.imshow(images[i])
        plt.axis('off')

    plt.show()

# %%
pipeline = DiffusionPipeline.from_pretrained('CompVis/stable-diffusion-v1-4')

test(pipeline)
# Out:
# Fetching 16 files:   0%|          | 0/16 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
pipeline = DiffusionPipeline.from_pretrained('./save')

test(pipeline)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
pipeline = DiffusionPipeline.from_pretrained(
    'lansinuote/diffusion.3.dream_boothimages')

test(pipeline)
# Out:
# Downloading (…)ain/model_index.json:   0%|          | 0.00/579 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# Downloading (…)rocessor_config.json:   0%|          | 0.00/520 [00:00<?, ?B/s]
# Downloading (…)_checker/config.json:   0%|          | 0.00/5.00k [00:00<?, ?B/s]
# Downloading (…)tokenizer/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# Downloading (…)cheduler_config.json:   0%|          | 0.00/341 [00:00<?, ?B/s]
# Downloading (…)_encoder/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading (…)"pytorch_model.bin";:   0%|          | 0.00/492M [00:00<?, ?B/s]
# Downloading (…)"pytorch_model.bin";:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/911 [00:00<?, ?B/s]
# Downloading (…)39b/unet/config.json:   0%|          | 0.00/1.07k [00:00<?, ?B/s]
# Downloading (…)e39b/vae/config.json:   0%|          | 0.00/699 [00:00<?, ?B/s]
# Downloading (…)tokenizer/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# Downloading (…)_pytorch_model.bin";:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# Downloading (…)_pytorch_model.bin";:   0%|          | 0.00/335M [00:00<?, ?B/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
